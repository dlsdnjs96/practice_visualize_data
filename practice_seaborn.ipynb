# %% [markdown]
# <a href="https://colab.research.google.com/github/dlsdnjs96/practice_visualize_data/blob/main/practice_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
sns.set(style='darkgrid')
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # relplot (relation plot)

# %%
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
# hue = 색상
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='size')

# %%
# style & hue
sns.relplot(x='total_bill', y='tip', data=tips, style='smoker', hue='size')

# %%
# color
sns.relplot(x='total_bill', y='tip', data=tips, hue='size', palette='Blues_d')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, size='size', hue='size', palette='Blues_d')

# %%
df = pd.DataFrame(dict(time=np.arange(500), value=np.random.randn(500).cumsum()))
df
# Out:
#      time     value
# 0       0 -0.479381
# 1       1 -0.165923
# 2       2 -0.061710
# 3       3 -1.011615
# 4       4 -1.510461
# ..    ...       ...
# 495   495  4.981859
# 496   496  5.557104
# 497   497  6.289363
# 498   498  6.523229
# 499   499  3.958292
#
# [500 rows x 2 columns]

# %%
sns.relplot(x='time', y='value', data=df, kind='line')

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', ci=None)
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', ci='sd')

# %%
sns.relplot(x='timepoint', y='signal', data=fmri, hue='region', style='event', kind='line')

# %% [markdown]
# # catplot (category plot)

# %%
sns.catplot(data=tips, x='day', y='total_bill')

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='swarm')

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='box')

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='violin', style='sex')

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='boxen')

# %%
sns.catplot(data=tips, x='day', kind='count')

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='bar')

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='point')

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='swarm', hue='sex')

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='violin', split=True, hue='sex')

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.catplot(data=titanic, x='sex', y='survived', hue='class', kind='bar')

# %% [markdown]
# # jointplot

# %%
df = pd.DataFrame(np.random.randn(500, 2), columns=['1', '2'])
df
# Out:
#             1         2
# 0    0.156284  0.196360
# 1    0.929913 -0.080779
# 2   -0.307672 -0.746766
# 3    1.350778  0.515015
# 4   -0.159561  0.436406
# ..        ...       ...
# 495  0.451211  0.840977
# 496 -0.582442 -1.197072
# 497 -0.483640 -0.577583
# 498  2.428578  1.641846
# 499 -0.511940 -0.788559
#
# [500 rows x 2 columns]

# %%
sns.relplot(x='1', y='2', data=df)

# %%
sns.jointplot(data=df, x='1', y='2')

# %%
sns.jointplot(data=df, x='1', y='2', kind='hex')

# %%
sns.jointplot(data=df, x='1', y='2', kind='kde')

# %%
sns.jointplot(data=df, x='1', y='2', kind='resid')

# %%
sns.jointplot(data=df, x='1', y='2', kind='reg')
